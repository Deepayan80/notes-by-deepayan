# %% [markdown]
# # Day - 7

# %% [markdown]
# # strings in python

# %% [markdown]
# # Creating strings in python

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
b = "we are learning python and this is our day 7 class"
print(b)
print(type(b))
# Out:
# we are learning python and this is our day 7 class
# <class 'str'>

# %% [markdown]
# # Multiline strings

# %%
b = '''Revenue Budget consists of the revenue receipts of the Government (Tax
revenues and Non-Tax revenues) and the revenue expenditure. Tax revenues
comprise proceeds of taxes and other duties levied by the Union. The estimates of
revenue receipts shown in the Annual Financial Statement take into account the
effect of various taxation proposals made in the Finance Bill. Non-tax receipts of
the Government mainly consist of interest and dividend on investments made by
the Government, fees and other receipts for services rendered by the Government.
Revenue expenditure is for the normal running of Government Departments and
for rendering of various services, making interest payments on debt, meeting
subsidies, grants in aid, etc. Broadly, the expenditure which does not result in
creation of assets for the Government of India, is treated as revenue expenditure.
All grants given to the State Governments/Union Territories and other parties
are also treated as revenue expenditure in the books of Union Government even
though some of the grants may be used for creation of capital assets by Grantee
bodies / entities.'''
print(b)
# Out:
# Revenue Budget consists of the revenue receipts of the Government (Tax
# revenues and Non-Tax revenues) and the revenue expenditure. Tax revenues
# comprise proceeds of taxes and other duties levied by the Union. The estimates of
# revenue receipts shown in the Annual Financial Statement take into account the
# effect of various taxation proposals made in the Finance Bill. Non-tax receipts of
# the Government mainly consist of interest and dividend on investments made by
# the Government, fees and other receipts for services rendered by the Government.
# Revenue expenditure is for the normal running of Government Departments and
# for rendering of various services, making interest payments on debt, meeting
# subsidies, grants in aid, etc. Broadly, the expenditure which does not result in
# creation of assets for the Government of India, is treated as revenue expenditure.
# All grants given to the State Governments/Union Territories and other parties
# ...

# %% [markdown]
# # Indexing of strings

# %%
a = "hello students"
print(a[11])
# Out:
# n

# %%
print(a[-2])
# Out:
# t

# %%
a = "How's your study going on ?"
print(a[11])
# Out:
# s

# %%
print(a[-1])
# Out:
# ?

# %% [markdown]
# # Slicing of strings

# %%
s = "Hello students how are you ?"
print(s[6:19])
# Out:
# students how

# %%
print(s[6:-9])
# Out:
# students how

# %%
print(s[0:20:2])
# Out:
# Hlosuet o

# %%
print(s[::-1])
# Out:
# ? uoy era woh stneduts olleH

# %% [markdown]
# # Finding the length of a string

# %%
print(len(b))
# Out:
# 1118

# %%
a = "This is our day 7 python class"
print(len(a))
# Out:
# 30

# %%
b = "hello world"
print(b)
print(len(b))
# Out:
# hello world
# 11

# %% [markdown]
# # upper method

# %%
a = "hello how are you"
print(a.upper())
a = a.upper()
# Out:
# HELLO HOW ARE YOU

# %% [markdown]
# # Lower Method

# %%
print(a)
print(a.lower())
# Out:
# HELLO HOW ARE YOU
# hello how are you

# %% [markdown]
# # Replace Function

# %%
print(a.replace("HELLO","bye"))
# Out:
# bye HOW ARE YOU

# %%
print(a.replace("H", "j"))
# Out:
# jELLO jOW ARE YOU

# %%
b = "hello World"
print(b)
print(b.replace("World", "students"))
# Out:
# hello World
# hello students

# %% [markdown]
# # Find Method

# %%
a = "python is great"
print(a.find("g"))
# Out:
# 10

# %%
print(a.find("p"))
# Out:
# 0
